# %%
import nltk 
from nltk import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("stopwords")
nltk.download('punkt_tab')
import re
# Out:
# [nltk_data] Downloading package punkt to /Users/Pranav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Pranav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Pranav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/Pranav/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
with open("ai1.txt", "r") as file: 
    text = file.read()

# %%
text = re.sub(r'[^a-zA-Z\s]', '', text)
text = re.sub(r'\s+', ' ', text)

# %%
text
# Out:
# 'The Hunger Games is set in a dystopian world called Panem It consists of the Capitol and twelve districts Every year the Capitol hosts a televised event called the Hunger Games One boy and one girl from each district are chosen to fight to the death Katniss Everdeen volunteers in place of her sister Prim She becomes the female tribute from District Peeta Mellark is the male tribute They travel to the Capitol by train The Capitol is rich and technologically advanced In contrast the districts are poor and oppressed The tributes receive training before entering the arena Katniss shows her archery skills during training She impresses the Gamemakers with her determination In the arena survival is key Katniss uses her hunting skills to survive She forms a temporary alliance with Rue Rue reminds Katniss of her sister After Rues death Katniss honors her This act defies the Capitol It sparks hope among the districts '

# %%
text = text.lower()

# %%
text
# Out:
# 'the hunger games is set in a dystopian world called panem it consists of the capitol and twelve districts every year the capitol hosts a televised event called the hunger games one boy and one girl from each district are chosen to fight to the death katniss everdeen volunteers in place of her sister prim she becomes the female tribute from district peeta mellark is the male tribute they travel to the capitol by train the capitol is rich and technologically advanced in contrast the districts are poor and oppressed the tributes receive training before entering the arena katniss shows her archery skills during training she impresses the gamemakers with her determination in the arena survival is key katniss uses her hunting skills to survive she forms a temporary alliance with rue rue reminds katniss of her sister after rues death katniss honors her this act defies the capitol it sparks hope among the districts '

# %%
tokens = word_tokenize(text)

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
stemmed_text = [stemmer.stem(word) for word in tokens]

# %%
stemmed_text
# Out:
# ['the',
#  'hunger',
#  'game',
#  'is',
#  'set',
#  'in',
#  'a',
#  'dystopian',
#  'world',
#  'call',
#  'panem',
#  'it',
#  'consist',
#  'of',
#  'the',
#  'capitol',
#  'and',
#  'twelv',
#  'district',
#  'everi',
#  'year',
#  'the',
#  'capitol',
#  'host',
#  'a',
#  'televis',
#  'event',
#  'call',
#  'the',
#  'hunger',
#  'game',
#  'one',
#  'boy',
#  'and',
#  'one',
#  'girl',
#  'from',
#  'each',
#  'district',
#  'are',
#  'chosen',
#  'to',
#  'fight',
#  'to',
#  'the',
#  'death',
#  'katniss',
#  'everdeen',
#  'volunt',
#  'in',
#  'place',
#  'of',
#  'her',
#  'sister',
#  'prim',
#  'she',
#  'becom',
#  'the',
#  'femal',
#  'tribut',
#  'from',
#  'district',
#  'peeta',
#  'mellark',
#  'is',
#  'the',
#  'male',
#  'tribut',
#  'they',
#  'travel',
#  'to',
#  'the',
#  'capitol',
#  'by',
#  'train',
#  'the',
#  'capitol',
#  'is',
#  'rich',
#  'and',
#  'technolog',
#  'advanc',
#  'in',
#  'contrast',
#  'the',
#  'district',
#  'are',
#  'poor',
#  'and',
#  'oppress',
#  'the',
#  'tribut',
#  'receiv',
#  'train',
#  'befor',
#  'enter',
#  'the',
#  'arena',
#  'katniss',
#  'show',
#  'her',
#  'archeri',
#  'skill',
#  'dure',
#  'train',
#  'she',
#  'impress',
#  'the',
#  'gamemak',
#  'with',
#  'her',
#  'determin',
#  'in',
#  'the',
#  'arena',
#  'surviv',
#  'is',
#  'key',
#  'katniss',
#  'use',
#  'her',
#  'hunt',
#  'skill',
#  'to',
#  'surviv',
#  'she',
#  'form',
#  'a',
#  'temporari',
#  'allianc',
#  'with',
#  'rue',
#  'rue',
#  'remind',
#  'katniss',
#  'of',
#  'her',
#  'sister',
#  'after',
#  'rue',
#  'death',
#  'katniss',
#  'honor',
#  'her',
#  'thi',
#  'act',
#  'defi',
#  'the',
#  'capitol',
#  'it',
#  'spark',
#  'hope',
#  'among',
#  'the',
#  'district']

# %%
lemmatized_text = [lemmatizer.lemmatize(word) for word in tokens]

# %%
lemmatized_text
# Out:
# ['the',
#  'hunger',
#  'game',
#  'is',
#  'set',
#  'in',
#  'a',
#  'dystopian',
#  'world',
#  'called',
#  'panem',
#  'it',
#  'consists',
#  'of',
#  'the',
#  'capitol',
#  'and',
#  'twelve',
#  'district',
#  'every',
#  'year',
#  'the',
#  'capitol',
#  'host',
#  'a',
#  'televised',
#  'event',
#  'called',
#  'the',
#  'hunger',
#  'game',
#  'one',
#  'boy',
#  'and',
#  'one',
#  'girl',
#  'from',
#  'each',
#  'district',
#  'are',
#  'chosen',
#  'to',
#  'fight',
#  'to',
#  'the',
#  'death',
#  'katniss',
#  'everdeen',
#  'volunteer',
#  'in',
#  'place',
#  'of',
#  'her',
#  'sister',
#  'prim',
#  'she',
#  'becomes',
#  'the',
#  'female',
#  'tribute',
#  'from',
#  'district',
#  'peeta',
#  'mellark',
#  'is',
#  'the',
#  'male',
#  'tribute',
#  'they',
#  'travel',
#  'to',
#  'the',
#  'capitol',
#  'by',
#  'train',
#  'the',
#  'capitol',
#  'is',
#  'rich',
#  'and',
#  'technologically',
#  'advanced',
#  'in',
#  'contrast',
#  'the',
#  'district',
#  'are',
#  'poor',
#  'and',
#  'oppressed',
#  'the',
#  'tribute',
#  'receive',
#  'training',
#  'before',
#  'entering',
#  'the',
#  'arena',
#  'katniss',
#  'show',
#  'her',
#  'archery',
#  'skill',
#  'during',
#  'training',
#  'she',
#  'impress',
#  'the',
#  'gamemakers',
#  'with',
#  'her',
#  'determination',
#  'in',
#  'the',
#  'arena',
#  'survival',
#  'is',
#  'key',
#  'katniss',
#  'us',
#  'her',
#  'hunting',
#  'skill',
#  'to',
#  'survive',
#  'she',
#  'form',
#  'a',
#  'temporary',
#  'alliance',
#  'with',
#  'rue',
#  'rue',
#  'reminds',
#  'katniss',
#  'of',
#  'her',
#  'sister',
#  'after',
#  'rue',
#  'death',
#  'katniss',
#  'honor',
#  'her',
#  'this',
#  'act',
#  'defies',
#  'the',
#  'capitol',
#  'it',
#  'spark',
#  'hope',
#  'among',
#  'the',
#  'district']

# %%
sets_of_three = []
for i in range(len(lemmatized_text) - 2):
    sets_of_three.append(lemmatized_text[i:i+3])
sets_of_three
# Out:
# [['the', 'hunger', 'game'],
#  ['hunger', 'game', 'is'],
#  ['game', 'is', 'set'],
#  ['is', 'set', 'in'],
#  ['set', 'in', 'a'],
#  ['in', 'a', 'dystopian'],
#  ['a', 'dystopian', 'world'],
#  ['dystopian', 'world', 'called'],
#  ['world', 'called', 'panem'],
#  ['called', 'panem', 'it'],
#  ['panem', 'it', 'consists'],
#  ['it', 'consists', 'of'],
#  ['consists', 'of', 'the'],
#  ['of', 'the', 'capitol'],
#  ['the', 'capitol', 'and'],
#  ['capitol', 'and', 'twelve'],
#  ['and', 'twelve', 'district'],
#  ['twelve', 'district', 'every'],
#  ['district', 'every', 'year'],
#  ['every', 'year', 'the'],
#  ['year', 'the', 'capitol'],
#  ['the', 'capitol', 'host'],
#  ['capitol', 'host', 'a'],
#  ['host', 'a', 'televised'],
#  ['a', 'televised', 'event'],
#  ['televised', 'event', 'called'],
#  ['event', 'called', 'the'],
#  ['called', 'the', 'hunger'],
#  ['the', 'hunger', 'game'],
#  ['hunger', 'game', 'one'],
#  ['game', 'one', 'boy'],
#  ['one', 'boy', 'and'],
#  ['boy', 'and', 'one'],
#  ['and', 'one', 'girl'],
#  ['one', 'girl', 'from'],
#  ['girl', 'from', 'each'],
#  ['from', 'each', 'district'],
#  ['each', 'district', 'are'],
#  ['district', 'are', 'chosen'],
#  ['are', 'chosen', 'to'],
#  ['chosen', 'to', 'fight'],
#  ['to', 'fight', 'to'],
#  ['fight', 'to', 'the'],
#  ['to', 'the', 'death'],
#  ['the', 'death', 'katniss'],
#  ['death', 'katniss', 'everdeen'],
#  ['katniss', 'everdeen', 'volunteer'],
#  ['everdeen', 'volunteer', 'in'],
#  ['volunteer', 'in', 'place'],
#  ['in', 'place', 'of'],
#  ['place', 'of', 'her'],
#  ['of', 'her', 'sister'],
#  ['her', 'sister', 'prim'],
#  ['sister', 'prim', 'she'],
#  ['prim', 'she', 'becomes'],
#  ['she', 'becomes', 'the'],
#  ['becomes', 'the', 'female'],
#  ['the', 'female', 'tribute'],
#  ['female', 'tribute', 'from'],
#  ['tribute', 'from', 'district'],
#  ['from', 'district', 'peeta'],
#  ['district', 'peeta', 'mellark'],
#  ['peeta', 'mellark', 'is'],
#  ['mellark', 'is', 'the'],
#  ['is', 'the', 'male'],
#  ['the', 'male', 'tribute'],
#  ['male', 'tribute', 'they'],
#  ['tribute', 'they', 'travel'],
#  ['they', 'travel', 'to'],
#  ['travel', 'to', 'the'],
#  ['to', 'the', 'capitol'],
#  ['the', 'capitol', 'by'],
#  ['capitol', 'by', 'train'],
#  ['by', 'train', 'the'],
#  ['train', 'the', 'capitol'],
#  ['the', 'capitol', 'is'],
#  ['capitol', 'is', 'rich'],
#  ['is', 'rich', 'and'],
#  ['rich', 'and', 'technologically'],
#  ['and', 'technologically', 'advanced'],
#  ['technologically', 'advanced', 'in'],
#  ['advanced', 'in', 'contrast'],
#  ['in', 'contrast', 'the'],
#  ['contrast', 'the', 'district'],
#  ['the', 'district', 'are'],
#  ['district', 'are', 'poor'],
#  ['are', 'poor', 'and'],
#  ['poor', 'and', 'oppressed'],
#  ['and', 'oppressed', 'the'],
#  ['oppressed', 'the', 'tribute'],
#  ['the', 'tribute', 'receive'],
#  ['tribute', 'receive', 'training'],
#  ['receive', 'training', 'before'],
#  ['training', 'before', 'entering'],
#  ['before', 'entering', 'the'],
#  ['entering', 'the', 'arena'],
#  ['the', 'arena', 'katniss'],
#  ['arena', 'katniss', 'show'],
#  ['katniss', 'show', 'her'],
#  ['show', 'her', 'archery'],
#  ['her', 'archery', 'skill'],
#  ['archery', 'skill', 'during'],
#  ['skill', 'during', 'training'],
#  ['during', 'training', 'she'],
#  ['training', 'she', 'impress'],
#  ['she', 'impress', 'the'],
#  ['impress', 'the', 'gamemakers'],
#  ['the', 'gamemakers', 'with'],
#  ['gamemakers', 'with', 'her'],
#  ['with', 'her', 'determination'],
#  ['her', 'determination', 'in'],
#  ['determination', 'in', 'the'],
#  ['in', 'the', 'arena'],
#  ['the', 'arena', 'survival'],
#  ['arena', 'survival', 'is'],
#  ['survival', 'is', 'key'],
#  ['is', 'key', 'katniss'],
#  ['key', 'katniss', 'us'],
#  ['katniss', 'us', 'her'],
#  ['us', 'her', 'hunting'],
#  ['her', 'hunting', 'skill'],
#  ['hunting', 'skill', 'to'],
#  ['skill', 'to', 'survive'],
#  ['to', 'survive', 'she'],
#  ['survive', 'she', 'form'],
#  ['she', 'form', 'a'],
#  ['form', 'a', 'temporary'],
#  ['a', 'temporary', 'alliance'],
#  ['temporary', 'alliance', 'with'],
#  ['alliance', 'with', 'rue'],
#  ['with', 'rue', 'rue'],
#  ['rue', 'rue', 'reminds'],
#  ['rue', 'reminds', 'katniss'],
#  ['reminds', 'katniss', 'of'],
#  ['katniss', 'of', 'her'],
#  ['of', 'her', 'sister'],
#  ['her', 'sister', 'after'],
#  ['sister', 'after', 'rue'],
#  ['after', 'rue', 'death'],
#  ['rue', 'death', 'katniss'],
#  ['death', 'katniss', 'honor'],
#  ['katniss', 'honor', 'her'],
#  ['honor', 'her', 'this'],
#  ['her', 'this', 'act'],
#  ['this', 'act', 'defies'],
#  ['act', 'defies', 'the'],
#  ['defies', 'the', 'capitol'],
#  ['the', 'capitol', 'it'],
#  ['capitol', 'it', 'spark'],
#  ['it', 'spark', 'hope'],
#  ['spark', 'hope', 'among'],
#  ['hope', 'among', 'the'],
#  ['among', 'the', 'district']]

# %%
import re
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')

# Step 1: Read the text file
with open('ai1.txt', 'r') as file:
    text = file.read()

# Step 2: Text cleaning (remove punctuation, numbers, extra spaces)
text = re.sub(r'[^A-Za-z\s]', '', text)  # Keep only letters and spaces
text = re.sub(r'\s+', ' ', text)  # Remove extra spaces

# Step 3: Convert to lowercase
text = text.lower()

# Step 4: Tokenization
tokens = word_tokenize(text)

# Step 5: Stemming
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in tokens]

# Step 6: Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in stemmed_tokens]

# Step 7: Create list of 3 consecutive words (trigrams)
trigrams = []
for i in range(len(lemmatized_tokens) - 2):
    trigram = ' '.join(lemmatized_tokens[i:i+3])
    trigrams.append(trigram)

# Final output
print("List of trigrams:")
for t in trigrams:
    print(t)
# Out:
# List of trigrams:
# the hunger game
# hunger game is
# game is set
# is set in
# set in a
# in a dystopian
# a dystopian world
# dystopian world call
# world call panem
# call panem it
# panem it consist
# it consist of
# consist of the
# of the capitol
# the capitol and
# capitol and twelv
# and twelv district
# twelv district everi
# district everi year
# everi year the
# year the capitol
# the capitol host
# capitol host a
# host a televis
# a televis event
# televis event call
# event call the
# call the hunger
# the hunger game
# hunger game one
# game one boy
# one boy and
# boy and one
# and one girl
# one girl from
# girl from each
# from each district
# each district are
# district are chosen
# are chosen to
# chosen to fight
# to fight to
# fight to the
# to the death
# the death katniss
# death katniss everdeen
# katniss everdeen volunt
# everdeen volunt in
# volunt in place
# in place of
# place of her
# of her sister
# her sister prim
# sister prim she
# prim she becom
# she becom the
# becom the femal
# the femal tribut
# femal tribut from
# tribut from district
# from district peeta
# district peeta mellark
# peeta mellark is
# mellark is the
# is the male
# the male tribut
# male tribut they
# tribut they travel
# they travel to
# travel to the
# to the capitol
# the capitol by
# capitol by train
# by train the
# train the capitol
# the capitol is
# capitol is rich
# is rich and
# rich and technolog
# and technolog advanc
# technolog advanc in
# advanc in contrast
# in contrast the
# contrast the district
# the district are
# district are poor
# are poor and
# poor and oppress
# and oppress the
# oppress the tribut
# the tribut receiv
# tribut receiv train
# receiv train befor
# train befor enter
# befor enter the
# enter the arena
# the arena katniss
# arena katniss show
# katniss show her
# show her archeri
# her archeri skill
# archeri skill dure
# skill dure train
# dure train she
# train she impress
# she impress the
# impress the gamemak
# the gamemak with
# gamemak with her
# with her determin
# her determin in
# determin in the
# in the arena
# the arena surviv
# arena surviv is
# surviv is key
# is key katniss
# key katniss use
# katniss use her
# use her hunt
# her hunt skill
# hunt skill to
# skill to surviv
# to surviv she
# surviv she form
# she form a
# form a temporari
# a temporari allianc
# temporari allianc with
# allianc with rue
# with rue rue
# rue rue remind
# rue remind katniss
# remind katniss of
# katniss of her
# of her sister
# her sister after
# sister after rue
# after rue death
# rue death katniss
# death katniss honor
# katniss honor her
# honor her thi
# her thi act
# thi act defi
# act defi the
# defi the capitol
# the capitol it
# capitol it spark
# it spark hope
# spark hope among
# hope among the
# among the district
# [nltk_data] Downloading package punkt to /Users/Pranav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Pranav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
